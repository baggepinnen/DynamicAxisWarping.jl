# %%
using TimeWarp
using TimeWarp.WarpPlots
pyplot() # use pyplot

# UCI data repository must be downloaded first, run TimeWarp.download_data()
data = TimeWarp.traindata("gun_point");
# Out:
# WARNING: Method definition show(IO, Base.Multimedia.MIME{:text/plain}, Plots.Plot) in module Plots at /Users/alex/.julia/v0.5/Plots/src/output.jl:168 overwritten at /Users/alex/.julia/v0.5/Plots/src/output.jl:241.

# %%
class = round(Int,data[:,1])
y = data[:,2:end]'

c = [ cl==1 ? :blue : :red for cl in class ]'
plot(y, linecolor=c, legend=false)
# Out:
# WARNING: the no-op `transpose` fallback is deprecated, and no more specific `transpose` method for Symbol exists. Consider `permutedims(x, [2, 1])` or writing a specific `transpose(x::Symbol)` method if appropriate.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in transpose(::Symbol) at ./deprecated.jl:771
#  in ctranspose at ./operators.jl:300 [inlined]
#  in (::Base.##143#144)(::Tuple{Int64,Symbol}) at ./<missing>:0
#  in copy!(::Array{Symbol,2}, ::Base.Generator{Base.Prod2{UnitRange{Int64},Array{Symbol,1}},Base.##143#144}) at ./abstractarray.jl:394
#  in ctranspose(::Array{Symbol,1}) at ./arraymath.jl:274
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request(::ZMQ.Socket, ::IJulia.Msg) at /Users/alex/.julia/v0.5/IJulia/src/execute_request.jl:164
#  in eventloop(::ZMQ.Socket) at /Users/alex/.julia/v0.5/IJulia/src/IJulia.jl:138
#  in (::IJulia.##25#31)() at ./task.jl:309
# while loading In[2], in expression starting on line 4
# <img src="data:image/png;base64,..." />

# %%
seqs = [ y[:,i] for i = 1:size(y,2) ]
avg, result = dba(seqs)
# Out:
# LoadError: UndefVarError: match2 not defined
# while loading In[3], in expression starting on line 2
#
#  in dba_iteration(::Array{Float64,1}, ::Array{Array{Float64,1},1}, ::Distances.SqEuclidean) at /Users/alex/.julia/v0.5/TimeWarp/src/dba.jl:94
#  in #dba#5(::Int64, ::Int64, ::Float64, ::Bool, ::Function, ::Array{Array{Float64,1},1}, ::Distances.SqEuclidean) at /Users/alex/.julia/v0.5/TimeWarp/src/dba.jl:50
#  in dba(::Array{Array{Float64,1},1}) at /Users/alex/.julia/v0.5/TimeWarp/src/dba.jl:36

# %%
n = median([ length(s) for s in seqs ])
# Out:
# 150.0
